# %%
import logging
from pymodbus.client import ModbusTcpClient
from random import randint, choice
from pymodbus.payload import BinaryPayloadBuilder, BinaryPayloadDecoder
from pymodbus.constants import Endian
from pymodbus.client import ModbusTcpClient as ModbusClient
from pymodbus.exceptions import ConnectionException
from pymodbus.pdu import ModbusRequest
from pymodbus.factory import ClientDecoder
from random import randint
import struct
import csv
# Configure logging
logging.basicConfig(filename='modbus_client.log',filemode='a',format='%(asctime)s %(levelname)-8s %(message)s',
                    level=logging.DEBUG,
                    datefmt='%Y-%m-%d %H:%M:%S')

logger = logging.getLogger(__name__)

def generate_specific_request(request_type, start_address, quantity=None, values=None):
    slaves = [0x01,0x02]
    if request_type == "read_coils": 
        results = client.read_coils(address=start_address, count= quantity,slave=choice(slaves))
        #print(results)
        return {'request_type': request_type,'start_address': start_address,'quantity': quantity,'values': values}
    elif request_type == "read_holding_registers":
        results =client.read_holding_registers(address=start_address, count=quantity,slave=choice(slaves))
        print(results)
        return {'request_type': request_type,'start_address': start_address,'quantity': quantity,'values': values}
    elif request_type == "read_discrete_inputs":
        results = client.read_discrete_inputs(address =start_address , count=quantity,slave=choice(slaves))
        print(results)
        return {'request_type': request_type,'start_address': start_address,'quantity': quantity,'values': values}
    elif request_type == "read_input_registers":
        results= client.read_input_registers(address=start_address, count=quantity,slave=choice(slaves))
        print(results)
        return {'request_type': request_type,'start_address': start_address,'quantity': quantity,'values': values}
    elif request_type == "write_single_coil":
        results = client.write_coil(address=start_address, value=values,slave=choice(slaves))
        print(results)
        return {'request_type': request_type,'start_address': start_address,'quantity': quantity,'values': values}
    elif request_type == "write_single_register":
        results = client.write_register(address= start_address, value=values,slave=choice(slaves))
        print(results)
        return {'request_type': request_type,'start_address': start_address,'quantity': quantity,'values': values}
    elif request_type == "write_multiple_coils":
        results= client.write_coils(address= start_address, values=[values,values,values],slave=choice(slaves))
        print(results)
        return {'request_type': request_type,'start_address': start_address,'quantity': quantity,'values': values}
    elif request_type == "write_multiple_registers":
        results= client.write_registers(address= start_address, values=[values,values,values],slave=choice(slaves))
        print(results)
        return {'request_type': request_type,'start_address': start_address,'quantity': quantity,'values': values}
    else:
        raise ValueError("Unsupported request type")

# Function to simulate generating multiple data frames
def generate_data_frames(num_requests=50000):  # Using a smaller number for demonstration
    data_frames = []
    for _ in range(num_requests):
        start_address = randint(0, 1000)  # Example range for address
        quantity = randint(1, 30)  # Example range for quantity
        values= choice([True,False,randint(0, 65535)])
        requests= ["read_coils","read_holding_registers","read_discrete_inputs","read_input_registers","write_single_coil","write_single_register","write_multiple_coils","write_multiple_registers"]
        request_type = choice(requests) # Choose request type here; extend logic for more types
        Query = generate_specific_request(request_type, start_address, quantity,values)
        data_frames.append(Query)
    return data_frames

def write_requests_to_csv(data_frames, filename="modbus_requests.csv"):
    with open(filename, mode='w', newline='') as file:
        writer = csv.writer(file)
        # Write the header
        writer.writerow(['Request Type', 'Start Address', 'Quantity', 'Values'])
        
        # Write the data rows
        for frame in data_frames:
            # Assuming frame is a dictionary with request details
            writer.writerow([frame['request_type'], frame.get('start_address', 'N/A'), frame.get('quantity', 'N/A'), frame.get('values', 'N/A')])

# %%
import logging
from pymodbus.client import ModbusTcpClient
from random import randint, choice
from pymodbus.payload import BinaryPayloadBuilder, BinaryPayloadDecoder
from pymodbus.constants import Endian
from pymodbus.client import ModbusTcpClient as ModbusClient
from pymodbus.exceptions import ConnectionException
from pymodbus.pdu import ModbusRequest
from pymodbus.factory import ClientDecoder
from random import randint
import struct
import csv
# Configure logging
logging.basicConfig(filename='modbus_client.log',filemode='a',format='%(asctime)s %(levelname)-8s %(message)s',
                    level=logging.DEBUG,
                    datefmt='%Y-%m-%d %H:%M:%S')

logger = logging.getLogger(__name__)

def generate_specific_request(request_type, start_address, quantity=None, values=None):
    slaves = [0x01,0x02]
    if request_type == "invalid_function_code":
        try:
            # Directly using ModbusRequest with a function code that doesn't exist (e.g., 0x99)
            request = ModbusRequest(function_code=0x99)
            results = client.execute(request)
            print("Sent request with invalid function code", results)
        except Exception as e:
            print("Error sending request with invalid function code:", e)
    # Condition for sending a request to test memory overflow
    elif request_type == "memory_overflow_test":
        try:
            # Example: attempting to write a large number of registers to test memory handling
            # Note: This might need adjustment to actually trigger an overflow condition based on the target server's capabilities
            large_payload = [randint(0, 65535) for _ in range(10000)]  # Large payload for testing
            results = client.write_registers(address=start_address, values=large_payload, slave=choice(slaves))
            print("Sent large payload to test memory overflow", results)
        except Exception as e:
            print("Error sending large payload:", e)
    if request_type == "read_coils": 
        results = client.read_coils(address=start_address, count= quantity,slave=choice(slaves))
        #print(results)
        return {'request_type': request_type,'start_address': start_address,'quantity': quantity,'values': values}
    elif request_type == "read_holding_registers":
        results =client.read_holding_registers(address=start_address, count=quantity,slave=choice(slaves))
        print(results)
        return {'request_type': request_type,'start_address': start_address,'quantity': quantity,'values': values}
    elif request_type == "read_discrete_inputs":
        results = client.read_discrete_inputs(address =start_address , count=quantity,slave=choice(slaves))
        print(results)
        return {'request_type': request_type,'start_address': start_address,'quantity': quantity,'values': values}
    elif request_type == "read_input_registers":
        results= client.read_input_registers(address=start_address, count=quantity,slave=choice(slaves))
        print(results)
        return {'request_type': request_type,'start_address': start_address,'quantity': quantity,'values': values}
    elif request_type == "write_single_coil":
        results = client.write_coil(address=start_address, value=values,slave=choice(slaves))
        print(results)
        return {'request_type': request_type,'start_address': start_address,'quantity': quantity,'values': values}
    elif request_type == "write_single_register":
        results = client.write_register(address= start_address, value=values,slave=choice(slaves))
        print(results)
        return {'request_type': request_type,'start_address': start_address,'quantity': quantity,'values': values}
    elif request_type == "write_multiple_coils":
        results= client.write_coils(address= start_address, values=[values,values,values],slave=choice(slaves))
        print(results)
        return {'request_type': request_type,'start_address': start_address,'quantity': quantity,'values': values}
    elif request_type == "write_multiple_registers":
        results= client.write_registers(address= start_address, values=[values,values,values],slave=choice(slaves))
        print(results)
        return {'request_type': request_type,'start_address': start_address,'quantity': quantity,'values': values}
    else:
        pass
        #raise ValueError("Unsupported request type")

# Function to simulate generating multiple data frames
def generate_data_frames(num_requests=500):  # Using a smaller number for demonstration
    data_frames = []
    for _ in range(num_requests):
        start_address = randint(0, 1000)  # Example range for address
        quantity = randint(1, 30)  # Example range for quantity
        values= choice([True,False,randint(0, 65535)])
        requests= ["invalid_function_code","memory_overflow_test","read_coils","read_holding_registers","read_discrete_inputs","read_input_registers","write_single_coil","write_single_register","write_multiple_coils","write_multiple_registers"]
        request_type = choice(requests) # Choose request type here; extend logic for more types
        Query = generate_specific_request(request_type, start_address, quantity,values)
        data_frames.append(Query)
    return data_frames

def write_requests_to_csv(data_frames, filename="modbus_requests.csv"):
    with open(filename, mode='w', newline='') as file:
        writer = csv.writer(file)
        # Write the header
        writer.writerow(['Request Type', 'Start Address', 'Quantity', 'Values'])
        
        # Write the data rows
        for frame in data_frames:
            # Assuming frame is a dictionary with request details
            writer.writerow([frame['request_type'], frame.get('start_address', 'N/A'), frame.get('quantity', 'N/A'), frame.get('values', 'N/A')])

# %%
import socket
import logging
from random import randint, choice
from pymodbus.client import ModbusTcpClient as ModbusClient
from pymodbus.exceptions import ConnectionException

# Configure logging
logging.basicConfig(filename='modbus_client.log', filemode='a', level=logging.DEBUG,
                    format='%(asctime)s:%(levelname)s:%(message)s')

client = ModbusClient('localhost', port=502)

def send_custom_request(data):
    host = 'localhost'  # Modbus server IP
    port = 502  # Modbus TCP port
    try:
        # Create socket and connect to server
        with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as sock:
            sock.connect((host, port))
            logging.info(f'Connected to {host}:{port}')

            # Send data
            sock.sendall(data)
            logging.info('Sent custom data to server')

            # Optionally receive response
            response = sock.recv(1024)
            logging.info(f'Response received: {response}')
    except Exception as e:
        logging.error(f'An error occurred: {e}')

def generate_specific_request(request_type, start_address, quantity=None, values=None):
    slaves = [0x01, 0x02]  # Assuming these are Modbus slave IDs

    if request_type == "invalid_function_code":
        data = bytes([
            0x00, 0x01,  # Transaction ID
            0x00, 0x00,  # Protocol ID
            0x00, 0x06,  # Length
            choice(slaves),  # Unit ID
            0x99,  # Invalid Function Code
            0x00, start_address,  # Starting Address (2 bytes)
            0x00, 0x01   # Quantity or Value (2 bytes)
        ])
        send_custom_request(data)
    elif request_type == "memory_overflow_test":
        data = bytes([
            0x00, 0x02,  # Transaction ID
            0x00, 0x00,  # Protocol ID
            0x81, 0x00,  # Incorrect Length for demonstration
        ]) + b'\x00' * 1024  # Example large payload
        send_custom_request(data)
    else:
        # Handling standard Modbus requests with pymodbus client
        if not client.is_socket_open():
            client.connect()
        if request_type == "read_coils": 
            results = client.read_coils(address=start_address, count= quantity,slave=choice(slaves))
            #print(results)
            return {'request_type': request_type,'start_address': start_address,'quantity': quantity,'values': values}
        elif request_type == "read_holding_registers":
            results =client.read_holding_registers(address=start_address, count=quantity,slave=choice(slaves))
            print(results)
            return {'request_type': request_type,'start_address': start_address,'quantity': quantity,'values': values}
        elif request_type == "read_discrete_inputs":
            results = client.read_discrete_inputs(address =start_address , count=quantity,slave=choice(slaves))
            print(results)
            return {'request_type': request_type,'start_address': start_address,'quantity': quantity,'values': values}
        elif request_type == "read_input_registers":
            results= client.read_input_registers(address=start_address, count=quantity,slave=choice(slaves))
            print(results)
            return {'request_type': request_type,'start_address': start_address,'quantity': quantity,'values': values}
        elif request_type == "write_single_coil":
            results = client.write_coil(address=start_address, value=values,slave=choice(slaves))
            print(results)
            return {'request_type': request_type,'start_address': start_address,'quantity': quantity,'values': values}
        elif request_type == "write_single_register":
            results = client.write_register(address= start_address, value=values,slave=choice(slaves))
            print(results)
            return {'request_type': request_type,'start_address': start_address,'quantity': quantity,'values': values}
        elif request_type == "write_multiple_coils":
            results= client.write_coils(address= start_address, values=[values,values,values],slave=choice(slaves))
            print(results)
            return {'request_type': request_type,'start_address': start_address,'quantity': quantity,'values': values}
        elif request_type == "write_multiple_registers":
            results= client.write_registers(address= start_address, values=[values,values,values],slave=choice(slaves))
            print(results)
            return {'request_type': request_type,'start_address': start_address,'quantity': quantity,'values': values}
        else:
            logging.error('Unsupported standard request type')
            
                
        if client.is_socket_open():
                client.close()

def generate_data_frames(num_requests=50):  # Using a smaller number for demonstration
    data_frames = []
    for _ in range(num_requests):
        start_address = randint(0, 1000)  # Example range for address
        quantity = randint(1, 30)  # Example range for quantity
        values= choice([True,False,randint(0, 65535)])
        requests= ["invalid_function_code","memory_overflow_test","read_coils","read_holding_registers","read_discrete_inputs","read_input_registers","write_single_coil","write_single_register","write_multiple_coils","write_multiple_registers"]
        request_type = choice(requests) # Choose request type here; extend logic for more types
        Query = generate_specific_request(request_type, start_address, quantity,values)
        data_frames.append(Query)
    return data_frames

# %%
if __name__ == "__main__":
    MODBUS_SERVER_IP = "127.0.0.1"
    MODBUS_SERVER_PORT = 502

    client = ModbusTcpClient(MODBUS_SERVER_IP, MODBUS_SERVER_PORT)
    client.connect()

    logger.info("Connected to Modbus server.")


    data_frames = generate_data_frames()
    #write_requests_to_csv(data_frames)

    client.close()
    logger.info("Disconnected from Modbus server.")

# %%
import socket
import logging

# Configure logging
logging.basicConfig(filename='modbus_client.log', filemode='a', level=logging.DEBUG,
                    format='%(asctime)s:%(levelname)s:%(message)s')

data = bytes([0xc3, 0x4d,  # Transaction ID
              0x00, 0x01,  # Protocol ID
              0x00, 0x06,  # Length
              0x02,        # Unit ID
              0x99,        # Function Code (Report Slave ID)
              0x03, 0x13,  # Output Address (97)
              0x00, 0x17]) # Value to write (Off)

# TCP connection details
host = 'localhost'
port = 502

try:
    # Create socket and connect to server
    sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    sock.connect((host, port))
    logging.info(f'Connected to {host}:{port}')

    # Send data
    hex_data = " ".join(f"{byte:02x}" for byte in data)
    logging.info(f'Sending data to server: {hex_data}')
    sock.sendall(data)

    # Receive response (if needed, depending on the use case)
    response = sock.recv(1024)
    logging.info(f'Response received: {response}')
    print("Response:", response)

except Exception as e:
    logging.error(f'An error occurred: {e}')
finally:
    # Close connection
    sock.close()
    logging.info('Connection closed')
# Out:
# Response: b'\xc3M\x00\x00\x001\x02\x04.\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'

# %%
import socket
import logging

# Configure logging
logging.basicConfig(filename='modbus_client.log', filemode='a', level=logging.DEBUG,
                    format='%(asctime)s:%(levelname)s:%(message)s')

# Generating a large payload for testing
large_data = bytes([0xc3, 0x4d,  # Transaction ID
                    0x00, 0x01,  # Protocol ID
                    0x00, 0x06,  # Length (Note: This will not match the actual length for illustrative purposes)
                    0x02,        # Unit ID
                    0x04,        # Function Code (Report Slave ID)
                   ]) + b'A' * 100  # Append 10,000 'A's to test buffer overflow

# TCP connection details
host = 'localhost'
port = 502

try:
    # Create socket and connect to server
    sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    sock.connect((host, port))
    logging.info(f'Connected to {host}:{port}')

    # Convert data to hexadecimal for logging (limiting to the first 100 bytes for readability)
    hex_data = " ".join(f"{byte:02x}" for byte in large_data[:100]) + "..."
    logging.info(f'Sending  data to server : {hex_data}')
    
    # Send data
    sock.sendall(large_data)

    # Note: Depending on the server's response to large data, you may or may not receive a response
    try:
        response = sock.recv(1024)
        logging.info(f'Response received: {response}')
        print("Response:", response)
    except socket.timeout:
        logging.info('No response received, potential overflow or server issue.')
except Exception as e:
    logging.error(f'An error occurred: {e}')
finally:
    # Close connection
    sock.close()
    logging.info('Connection closed')
# Out:
# Response: b''
